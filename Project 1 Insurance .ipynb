# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filelocation = 'C:/Users/PC ADM/insurance.csv'
df = pd.read_csv(filelocation)

# %%
# Read data
print(df)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#Analisa Descriptive
#1.Rata-rata umur pengguna
#2.Rata-rata BMI Perokok
#3.Apakah variansi dari data charges perokok dan non perokok sama?
#4.Apakah rata rata umur perempuan dan laki-laki yang merokok sama?
#5.Mana yang lebih tinggi, rata rata tagihan kesehatan perokok atau non merokok?

# %%
#1.Rata-rata umur pengguna
np.mean(df.age)
# Out:
# 39.20702541106129

# %%
sns.set()

# %%
# Visualisasi Umur
plt.hist(df['age'], color= 'blue', edgecolor = 'black', alpha = 0.6)
plt.xlabel('Age')
plt.show();

sns.distplot(df['age'], color= 'Blue');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Count Manual Mean Of Age, Total Row 1338
df.age.sum()
# Out:
# 52459

# %%
Mean_Manual = 52459/1338
print(Mean_Manual)
# Out:
# 39.20702541106129

# %%
#2 Mean BMI Perokok
df['bmi'][(df['smoker'] == 'yes')].mean()
# Out:
# 30.708448905109503

# %%
#Visual dari BMI
plt.hist(df['bmi'] [(df['smoker'] == 'yes')], color= 'red', edgecolor = 'black', alpha = 0.6)
plt.xlabel('BMI Perokok')
plt.show();

sns.distplot(df['bmi'], color= 'red');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3.Apakah variansi dari data charges perokok dan non perokok sama?
charge_perokok = np.var(df['charges'][df['smoker'] == 'yes'])
charge_NonPerokok = np.var(df['charges'][df['smoker'] == 'no'])

# %%
if charge_perokok > charge_NonPerokok:
    print(f"variansi tagihan perokok lebih besar sebesar {charge_perokok} dibanding variansi tagihan non perokok yang hanya sebesar {charge_NonPerokok}")
else:
    print(f"variansi tagihan non perokok lebih besar sebesar {charge_NonPerokok} dibanding variansi tagihan perokok yang hanya sebesar {charge_perokok}")
# Out:
# variansi tagihan perokok lebih besar sebesar 132721153.13625304 dibanding variansi tagihan non perokok yang hanya sebesar 35891656.00316425

# %%
#Buktikan Dengan Histogram dan Density
#3.1.a.Charges Perokok
plt.hist(df['charges'] [(df['smoker'] == 'yes')], color= 'green', edgecolor = 'blue', alpha = 0.6)
plt.xlabel('Charges yes')
plt.show();

sns.distplot(df['charges'], color= 'green');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3.1.b Charges non perokok
plt.hist(df['charges'] [(df['smoker'] == 'no')], color= 'green', edgecolor = 'Red', alpha = 0.6)
plt.xlabel('Charges No')
plt.show();

sns.distplot(df['charges'], color= 'green');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#4.Apakah rata rata umur perempuan dan laki-laki yang merokok sama?

# %%
#Rata rata umur laki-laki yang merokok
df['age'] [(df['sex'] == 'male') & (df['smoker'] == 'yes')].mean()
# Out:
# 38.44654088050314

# %%
#Rata rata umur Perempuan yang merokok
df['age'] [(df['sex'] == 'female') & (df['smoker'] == 'yes')].mean()
# Out:
# 38.608695652173914

# %%
#Dapat disimpulkan bahwa rata-rata umur perokok baik perempuan maupun laki-laki hampir sama
#Rata-rata Umur Perokok laki laki 38.45 dan umur perempuan perokok 38.61

# %%
#4.1.a.Rata-rata Umur Laki-laki Perokok
plt.hist(df['age'] [(df['sex'] == 'male') & (df['smoker'] == 'yes')], color= 'purple', edgecolor = 'Black', alpha = 0.6 )
plt.xlabel('umur Laki-laki Perokok')
plt.show();

sns.distplot(df['age'] [(df['sex'] == 'male') & (df['smoker'] == 'yes')], color= 'purple');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#4.1.a.Rata-rata Umur wanita Perokok
plt.hist(df['age'] [(df['sex'] == 'female') & (df['smoker'] == 'yes')], color= 'purple', edgecolor = 'Blue', alpha = 0.6 )
plt.xlabel('Umur Perempuan Perokok')
plt.show();

sns.distplot(df['age'] [(df['sex'] == 'female') & (df['smoker'] == 'yes')], color= 'purple');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#5.Mana yang lebih tinggi, rata rata tagihan kesehatan perokok atau non merokok?

# %%
#5.1.a.Rata-rata Tagihan Kesehatan Perokok
mean_charges_smoker_yes = np.mean(df['charges'][df['smoker'] == 'yes'])
mean_charges_smoker_no = np.mean(df['charges'][df['smoker'] == 'no'])

# %%
if mean_charges_smoker_yes > mean_charges_smoker_no:
    print(f"Rata-rata charges perokok lebih besar yaitu senilai {mean_charges_smoker_yes} Dollar dibanding yang tidak merokok yang hanya sebesar {mean_charges_smoker_no}")
else:
    print(f"Rata-rata charges non perokok lebih besar yaitu sebesar{mean_charges_smoker_no} Dollar dibanding yang merokok yang hanya sebesar {mean_charges_smoker_yes}")
# Out:
# Rata-rata charges perokok lebih besar yaitu senilai 32050.23183153285 Dollar dibanding yang tidak merokok yang hanya sebesar 8434.268297856199

# %%
#Visual Perokok dan Non Perokok
plt.hist(df['charges'] [(df['smoker'] == 'yes')], color= 'yellow', edgecolor = 'Blue', alpha = 0.6 )
plt.xlabel('Charges Perokok')
plt.show();

sns.distplot(df['charges'] [(df['smoker'] == 'yes')], color= 'yellow');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.hist(df['charges'] [(df['smoker'] == 'no')], color= 'yellow', edgecolor = 'Blue', alpha = 0.6 )
plt.xlabel('Charges Non Perokok')
plt.show();

sns.distplot(df['charges'] [(df['smoker'] == 'no')], color= 'yellow');
# Out:
# C:\Users\PC ADM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Mencari Nilai PMF
#1 Gender Mana Tagihan Paling Tinggi 
#2 Distribusi Peluang Tagihan tiap Region
#3 proporsi paling tinggi perokok atau non perokok
#4 Berapa peluang seseorang tersebut adalah laki-laki diketahui dia adalah perokok?

# %%
#1 Gender Mana Tagihan Paling Tinggi

# %%
#Tagihan Laki-laki
df['charges'][df['sex'] == 'male'].sum()
# Out:
# 9434763.79614

# %%
#Tagihan Perempuan
df['charges'][df['sex'] == 'female'].sum()
# Out:
# 8321061.194619

# %%
#Visual Tagihan Based Gender
x = ['male', 'female']
h = [9434763.80, 8321061.19]
C = ['Blue', 'red']
plt.bar(x,h,color=C)
plt.xlabel('Gender')
plt.ylabel('Total_Charges_(M$)')
plt.title('Total Tagihan berdasarkan Gender')
for i in range(len(x)):
    plt.text(i, h[i], h[i], ha='center', va='bottom')
plt.show()

# %%
#Jika Menggunakan Rata-rata Chargers

# %%
#Mean Charges laki laki
df['charges'][df['sex'] == 'male'].mean()
# Out:
# 13956.751177721886

# %%
#Mean Charges laki laki
df['charges'][df['sex'] == 'female'].mean()
# Out:
# 12569.57884383534

# %%
#Visual Rata-rata Charge berdasarkan gender
x = ['male', 'female']
h = [13956.76, 12569.58]
C = ['Blue', 'red']
plt.bar(x,h,color=C)
plt.xlabel('Gender')
plt.ylabel('Rata-rata_Tagihan_($)')
plt.title('Rata-rata Tagihan Berdasarkan Gender')
for i in range(len(x)):
    plt.text(i, h[i], h[i], ha='center', va='bottom')
plt.show()

# %%
#2 Distribusi Peluang Tagihan tiap Region
#Total Row dari Charges
df['charges'].count()
# Out:
# 1338

# %%
#Kejadian Region southwest
df[df['region'] == ('southwest')] ['charges'].count()
# Out:
# 325

# %%
#Kejadian Region southeast
df[df['region'] == ('southeast')] ['charges'].count()
# Out:
# 364

# %%
#Kejadian Region northwest
df[df['region'] == ('northwest')] ['charges'].count()
# Out:
# 325

# %%
#Kejadian Region northeast
df[df['region'] == ('northeast')] ['charges'].count()
# Out:
# 324

# %%
#Peluang Region southwest Memiliki Tagihan
Peluang_Region_Southwest_Memiliki_Tagihan = 325/1338

# %%
print(Peluang_Region_Southwest_Memiliki_Tagihan)
# Out:
# 0.2428998505231689

# %%
#Peluang Region southeast Memiliki Tagihan
Peluang_Region_Southeast_Memiliki_Tagihan = 364/1338

# %%
print(Peluang_Region_Southeast_Memiliki_Tagihan)
# Out:
# 0.27204783258594917

# %%
#Peluang Region Northwest Memiliki Tagihan
Peluang_Region_Northwest_Memiliki_Tagihan = 325/1338

# %%
print(Peluang_Region_Northwest_Memiliki_Tagihan)
# Out:
# 0.2428998505231689

# %%
#Peluang Region Northeast Memiliki Tagihan
Peluang_Region_Northeast_Memiliki_Tagihan = 324/1338

# %%
print(Peluang_Region_Northeast_Memiliki_Tagihan)
# Out:
# 0.242152466367713

# %%
#Distribusi Peluang Setiap Region Memiliki Tagihan 
x = ['Southwest', 'southeast', 'Northwest', 'Northeast']
h = [0.243, 0.27, 0.243, 0.242 ]
C = ['Blue', 'red', 'yellow', 'orange']
plt.bar(x,h,color=C)
plt.xlabel('Region')
plt.ylabel('Peluang')
plt.title('Peluang Setiap Region Memiliki Tagihan')
for i in range(len(x)):
    plt.text(i, h[i], h[i], ha='center', va='bottom')
plt.show()

# %%
#Proporsi Antara Perokok dan Non Perokok
df[df['smoker'] == ('yes')].count()
# Out:
# age         274
# sex         274
# bmi         274
# children    274
# smoker      274
# region      274
# charges     274
# dtype: int64

# %%
Persentase_Perokok = 274*100/1338

# %%
print(Persentase_Perokok)
# Out:
# 20.47832585949178

# %%
df[df['smoker'] == ('no')].count()
# Out:
# age         1064
# sex         1064
# bmi         1064
# children    1064
# smoker      1064
# region      1064
# charges     1064
# dtype: int64

# %%
Persentase_Non_Perokok = 1064*100/1338
print(Persentase_Non_Perokok)
# Out:
# 79.52167414050822

# %%
#Proporsi Antara Perokok dan Non Perokok
x = ['Perokok', 'Non Perokok']
h = [20.48, 79.52]
C = ['Blue', 'red']
plt.bar(x,h,color=C)
plt.xlabel('Merokok Atau Tidaknya')
plt.ylabel('persentase_(%)')
plt.title('Proporsi Antara Perokok dan Non Perokok')
for i in range(len(x)):
    plt.text(i, h[i], h[i], ha='center', va='bottom')
plt.show()

# %%
#4 Berapa peluang seseorang tersebut adalah laki-laki diketahui dia adalah perokok?
#Total Sample Perokok = 274
Kejadian_Seseorang_merokok = (df[df['smoker'] == "yes"]).count()

# %%
print(Kejadian_Seseorang_merokok)
# Out:
# age         274
# sex         274
# bmi         274
# children    274
# smoker      274
# region      274
# charges     274
# dtype: int64

# %%
kejadian_Laki_laki_diketahui_merokok = (df[df['smoker'] == "yes"] [df['sex'] == "male"]).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\531184192.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   kejadian_Laki_laki_diketahui_merokok = (df[df['smoker'] == "yes"] [df['sex'] == "male"]).count()

# %%
Peluang_Laki_Laki_diketahui_Perokok = kejadian_Laki_laki_diketahui_merokok/274

# %%
print(Peluang_Laki_Laki_diketahui_Perokok)
# Out:
# age         0.580292
# sex         0.580292
# bmi         0.580292
# children    0.580292
# smoker      0.580292
# region      0.580292
# charges     0.580292
# dtype: float64

# %%
Kejadian_Perempuan_diketahui_merokok = (df[df['smoker'] == "yes"] [df['sex'] == "female"]).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\856566545.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_Perempuan_diketahui_merokok = (df[df['smoker'] == "yes"] [df['sex'] == "female"]).count()

# %%
Peluang_Perempuan_diketahui_Perokok =Kejadian_Perempuan_diketahui_merokok /274

# %%
print(Peluang_Perempuan_diketahui_Perokok)
# Out:
# age         0.419708
# sex         0.419708
# bmi         0.419708
# children    0.419708
# smoker      0.419708
# region      0.419708
# charges     0.419708
# dtype: float64

# %%
x = ['laki laki Perokok', 'Perempuan Perokok']
h = [0.581, 0.419]
C = ['Blue', 'Blue']
plt.bar(x,h,color=C)
plt.xlabel('Peluang')
plt.ylabel('Nilai Peluang')
plt.title('Peluang Seseorang merokok berdasarkan gender')
for i in range(len(x)):
    plt.text(i, h[i], h[i], ha='center', va='bottom')
plt.show()

# %%
#3 - Analisa Variabel Kontinu (CDF)
#Mencari peluang besar tagihan berdasarkan BMI
#Mencari kemungkin terjadi, seorang perokok dengan BMI diatas 25 akan mendapatkan tagihan kesehatan di atas 16.700.
#Berapa peluang seseorang acak tagihan kesehatannya diatas 16.7k diketahui dia adalah perokok
#Mana yang lebih mungkin terjadi
   #a. Seseorang dengan BMI diatas 25 mendapatkan tagihan kesehatan diatas 16.7k,atau
   #b. Seseorang dengan BMI dibawah 25 mendapatkan tagihan kesehatan diatas 16.7k
#Mana yang lebih mungkin terjadi
   #a. Seseorang perokok dengan BMI diatas 25 mendapatkan tagihan kesehatan diatas 16.7k, atau
   #b. Seseorang non perokok dengan BMI diatas 25 mendapatkan tagihan kesehatan diatas 16.7k

# %%
#Mencari kemungkin terjadi, seorang perokok dengan BMI diatas 25 akan mendapatkan tagihan kesehatan di atas 16.700.
#Total Kejadian adalah 1338
Kejadian_BMI_diatas_25_Charges_diatas_16700 = (df[df['bmi'] > 25.00] [df['charges'] > 16700]).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\3474446401.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_BMI_diatas_25_Charges_diatas_16700 = (df[df['bmi'] > 25.00] [df['charges'] > 16700]).count()

# %%
Peluang_BMI_diatas_25_Charges_diatas_16700 = Kejadian_BMI_diatas_25_Charges_diatas_16700/1338

# %%
print(Peluang_BMI_diatas_25_Charges_diatas_16700)
# Out:
# age         0.21151
# sex         0.21151
# bmi         0.21151
# children    0.21151
# smoker      0.21151
# region      0.21151
# charges     0.21151
# dtype: float64

# %%
#seorang perokok dengan BMI dibawah 25 akan mendapatkan tagihan kesehatan di atas 16.700.
Kejadian_BMI_dibawah_25_Charges_diatas_16700 = (df[df['bmi'] < 25.00] [df['charges'] > 16700]).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\1609137273.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_BMI_dibawah_25_Charges_diatas_16700 = (df[df['bmi'] < 25.00] [df['charges'] > 16700]).count()

# %%
Peluang_Seorang_BMI_dibawah_25_Charges_diatas_16700 = Kejadian_BMI_dibawah_25_Charges_diatas_16700/1338

# %%
print(Peluang_Seorang_BMI_dibawah_25_Charges_diatas_16700)
# Out:
# age         0.038117
# sex         0.038117
# bmi         0.038117
# children    0.038117
# smoker      0.038117
# region      0.038117
# charges     0.038117
# dtype: float64

# %%
#Berapa peluang seseorang acak tagihan kesehatannya diatas 16.7k diketahui dia adalah perokok
#Total Kejadian 1338
Kejadian_seorang_kena_charge_diatas_16700_diketahui_dia_perokok = (df[df['charges'] > 16700] [df['smoker'] == ('yes')]).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\601285334.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_seorang_kena_charge_diatas_16700_diketahui_dia_perokok = (df[df['charges'] > 16700] [df['smoker'] == ('yes')]).count()

# %%
Peluang_seorang_kena_charge_diatas_16700_diketahui_dia_perokok = Kejadian_seorang_kena_charge_diatas_16700_diketahui_dia_perokok/1338

# %%
print(Peluang_seorang_kena_charge_diatas_16700_diketahui_dia_perokok)
# Out:
# age         0.189836
# sex         0.189836
# bmi         0.189836
# children    0.189836
# smoker      0.189836
# region      0.189836
# charges     0.189836
# dtype: float64

# %%
#Mana yang lebih mungkin terjadi
   #a. Seseorang perokok dengan BMI diatas 25 mendapatkan tagihan kesehatan diatas 16.7k, atau
   #b. Seseorang non perokok dengan BMI diatas 25 mendapatkan tagihan kesehatan diatas 16.7k

# %%
#Merokok, BMI diatas 25 dengan tagihan diatas 17600
#Total Kejadian 1338

# %%
Kejadian_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = (df[df['bmi'] > 25.00] [df['charges'] > 16700] [df['smoker'] == 'yes']).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\1133418230.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = (df[df['bmi'] > 25.00] [df['charges'] > 16700] [df['smoker'] == 'yes']).count()

# %%
Peluang_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = Kejadian_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600/1338

# %%
print(Peluang_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600)
# Out:
# age         0.160688
# sex         0.160688
# bmi         0.160688
# children    0.160688
# smoker      0.160688
# region      0.160688
# charges     0.160688
# dtype: float64

# %%
#NonPerokok, BMI diatas 25 dengan tagihan diatas 17600
#Total Kejadian 1338

# %%
Kejadian_Non_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = (df[df['bmi'] > 25.00] [df['charges'] > 16700] [df['smoker'] == 'no']).count()
# Out:
# C:\Users\PC ADM\AppData\Local\Temp\ipykernel_2740\268933608.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Kejadian_Non_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = (df[df['bmi'] > 25.00] [df['charges'] > 16700] [df['smoker'] == 'no']).count()

# %%
Peluang_Non_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600 = Kejadian_Non_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600/1338

# %%
print(Peluang_Non_Perokok_BMI_diatas_25_dengan_tagihan_diatas_17600)
# Out:
# age         0.050822
# sex         0.050822
# bmi         0.050822
# children    0.050822
# smoker      0.050822
# region      0.050822
# charges     0.050822
# dtype: float64

# %%
#Yang Lebih mungkin adalah peluang Seorang perokok dengan BMI diatas 25 dan tagihan diatas 17600

# %%
#4 - Analisa Korelasi Variabel
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
corr = df.corr()
f,ax = plt.subplots(figsize =(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = ".2f",ax=ax)
plt.show()

# %%
#Pengujian Hipotesis
#1. Tagihan kesehatan perokok lebih tinggi daripada tagihan kesehatan non perokok
#2. Tagihan kesehatan dengan BMI diatas 25 lebih tinggi daripada tagihan kesehatan dengan BMI dibawah 25

# %%
import scipy.stats as stats

# %%
Langkah-langkah uji hipotesis:

    Menyatakan hipotesis null dan alternatif hipotesis
    Menghitung uji statistik
    Menentukan aturan keputusan
    Menyatakan rejection decision
    Kesimpulan

# %%
import scipy.stats as stats
from sklearn.preprocessing import LabelEncoder

# %%
#1. Tagihan kesehatan perokok lebih tinggi daripada tagihan kesehatan non perokok
Hypotesis :
    𝐻0:Tagihan Kesehatan Perokok kurang dari atau sama dengan tagihan kesehatan non perokok
    𝐻1:Tagihan Kesehatan Perokok lebih tinggi atau sama dengan tagihan kesehatan non perokok

# %%
Alpha = 0.05

# %%
x = df[df['smoker'] == ('yes')]['charges']
y = df[df['smoker'] == ('no')]['charges']

# performing an independent t-test
t, p_value  = stats.ttest_ind(x,y, axis = 0)  

print(p_value)
# Out:
# 8.271435842179102e-283

# %%
print('Pengambilan keputusan') 
    
#Jika P_value Lebih besar dari alpha
if p_value > Alpha: 
    print('Terima 𝐻0')
#Jika P_Value lebih kecil dari Alpha
else:
    print('tolak 𝐻0')
# Out:
# Pengambilan keputusan
# tolak 𝐻0

# %%
#2. Tagihan kesehatan dengan BMI diatas 25 lebih tinggi daripada tagihan kesehatan dengan BMI dibawah 25
Hypotesis :
    𝐻0:Tagihan Kesehatan dengan BMI Diatas 25 tidak lebih tinggi atau sama dengan tagihan kesehatan BMI dibawah 25
    𝐻1:Tagihan kesehatan dengan BMI diatas 25 lebih tinggi daripada tagihan kesehatan dengan BMI dibawah 25

# %%
Alpha = 0.05

# %%
x = df[df['bmi'] > 25.00] ['charges']
y = df[df['bmi'] < 25.00] ['charges']

# performing an independent t-test
t, p_value  = stats.ttest_ind(x,y, axis = 0)  

print(p_value)
# Out:
# 1.7916455594610296e-05

# %%
print('Pengambilan keputusan') 
    
#Jika P_value Lebih besar dari alpha
if p_value > Alpha: 
    print('Terima 𝐻0')
#Jika P_Value lebih kecil dari Alpha
else:
    print('tolak 𝐻0')
# Out:
# Pengambilan keputusan
# tolak 𝐻0

# %%
#3.Apakah Jenis kelamin berpengaruh pada kebiasaan merokok?
Hypotesis :
    𝐻0:Jenis kelamin tidak berpengaruh pada kebiasaan merokok
    𝐻1:Jenis Kelamin Berpengaruh pada kebiasaan merokok

# %%
Alpha = 0.05

# %%
crosstab = pd.crosstab(df['sex'],df['smoker']) 
chi, p_value, dof, expected =  stats.chi2_contingency(crosstab)

print(p_value)
# Out:
# 0.006548143503580696

# %%
print('Pengambilan keputusan') 
    
#Jika P_value Lebih besar dari alpha
if p_value > Alpha: 
    print('Terima 𝐻0')
#Jika P_Value lebih kecil dari Alpha
else:
    print('tolak 𝐻0')
# Out:
# Pengambilan keputusan
# tolak 𝐻0
